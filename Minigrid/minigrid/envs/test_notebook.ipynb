# %%
from __future__ import annotations

from minigrid.core.grid import Grid
from minigrid.core.mission import MissionSpace
from minigrid.core.world_object import Door, Goal, Key
from minigrid.minigrid_env import MiniGridEnv
from doorkey import DoorKeyEnv
from minigrid.manual_control import ManualControl

def main():
    # Instantiate your custom DoorKeyEnv
    env = DoorKeyEnv(render_mode="human")

    # Start manual control interface
    manual = ManualControl(env, seed=42)
    manual.start()

if __name__ == "__main__":
    main()
# Out:
# pressed right
# step=1, reward=0.00
# pressed right
# step=2, reward=0.00
# pressed up
# step=3, reward=0.00
# pressed up
# step=4, reward=0.00
# pressed up
# step=5, reward=0.00
# pressed up
# step=6, reward=0.00
# pressed tab
# step=7, reward=0.00
# pressed right
# step=8, reward=0.00
# pressed right
# step=9, reward=0.00
# pressed down
# down
# pressed down
# down
# pressed up
# step=10, reward=0.00
# pressed left
# step=11, reward=0.00
# pressed space
# step=12, reward=0.00
# pressed right
# step=13, reward=0.00
# pressed right
# step=14, reward=0.00
# pressed right
# step=15, reward=0.00
# pressed right
# step=16, reward=0.00
# pressed up
# step=17, reward=0.00
# pressed up
# step=18, reward=0.00
# pressed up
# step=19, reward=0.00
# pressed right
# step=20, reward=0.00
# pressed right
# step=21, reward=0.00
# pressed right
# step=22, reward=0.00
# pressed right
# step=23, reward=0.00
# pressed right
# step=24, reward=0.00
# pressed up
# step=25, reward=0.00
# pressed up
# step=26, reward=0.00
# pressed up
# step=27, reward=0.00
# pressed up
# step=28, reward=0.00
# pressed left
# step=29, reward=0.00
# pressed up
# step=30, reward=0.00
# pressed up
# step=31, reward=0.96
# terminated!
# pressed left
# step=1, reward=0.00
# pressed left
# step=2, reward=0.00
# pressed up
# step=3, reward=0.00
# pressed up
# step=4, reward=0.00
# pressed up
# step=5, reward=0.00
# pressed tab
# step=6, reward=0.00
# pressed escape
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 19
#      16     manual.start()
#      18 if __name__ == "__main__":
# ---> 19     main()
#
# Cell In[1], line 16, in main()
#      14 # Start manual control interface
#      15 manual = ManualControl(env, seed=42)
# ---> 16 manual.start()
#
# File c:\Users\nsmith3\AppData\Local\anaconda3\envs\RLHF\Lib\site-packages\minigrid\manual_control.py:29, in ManualControl.start(self)
#      26 self.reset(self.seed)
#      28 while not self.closed:
# ---> 29     for event in pygame.event.get():
#      30         if event.type == pygame.QUIT:
#      31             self.env.close()
#
# error: video system not initialized

# %%
from __future__ import annotations
from minigrid.core.grid import Grid
from minigrid.core.mission import MissionSpace
from minigrid.core.world_object import Door, Goal, Key
from minigrid.minigrid_env import MiniGridEnv
from test_envs import TestEnv
from minigrid.manual_control import ManualControl


# Instantiate your custom DoorKeyEnv
env = TestEnv(render_mode="human")
print("step method:", env.step.__func__.__qualname__)

# Start manual control interface
manual = ManualControl(env, seed=42)
manual.start()
# Out:
# step method: TestEnv.step
# pressed left
# step=1, reward=0.00
# pressed up
# step=2, reward=0.00
# pressed tab
# carrying <minigrid.core.world_object.Key object at 0x0000021D2F6BB810>
# step=3, reward=0.00
# pressed left
# step=4, reward=0.00
# pressed up
# step=5, reward=0.00
# pressed up
# step=6, reward=0.00
# pressed right
# step=7, reward=0.00
# pressed up
# step=8, reward=0.00
# pressed space
# step=9, reward=0.00
# pressed up
# step=10, reward=0.00
# pressed up
# step=11, reward=0.00
# pressed left shift
# step=12, reward=0.00
# pressed right
# step=13, reward=0.00
# pressed up
# step=14, reward=0.00
# pressed up
# step=15, reward=0.00
# pressed up
# step=16, reward=0.00
# pressed left
# step=17, reward=0.00
# pressed up
# step=18, reward=0.00
# pressed up
# step=19, reward=0.00
# pressed tab
# carrying <minigrid.core.world_object.Box object at 0x0000021D2F6A99D0>
# carrying <minigrid.core.world_object.Box object at 0x0000021D2F6A99D0>
# step=20, reward=0.94
# terminated!
# pressed escape
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[21], line 16
#      14 # Start manual control interface
#      15 manual = ManualControl(env, seed=42)
# ---> 16 manual.start()
#
# File c:\Users\nsmith3\AppData\Local\anaconda3\envs\RLHF\Lib\site-packages\minigrid\manual_control.py:29, in ManualControl.start(self)
#      26 self.reset(self.seed)
#      28 while not self.closed:
# ---> 29     for event in pygame.event.get():
#      30         if event.type == pygame.QUIT:
#      31             self.env.close()
#
# error: video system not initialized
